# %%
# Colab Connection Diagnostics - Run this cell to verify the connection is working properly
import sys
import platform

print("Python:", sys.version.split()[0])
print("platform:", platform.platform())

# Whether to run on Colab cloud
try:
    import google.colab
    IN_COLAB = True
    print("Operating environment: ✅ Google Colab cloud")
except ImportError:
    IN_COLAB = False
    print("Running environment: ❌ Local kernel (not connected to Colab)")

# GPU detection
try:
    import torch
    cuda_ok = torch.cuda.is_available()
    print("PyTorch CUDA:", "✅ Available" if cuda_ok else "❌ Not available")
    if cuda_ok:
        print("GPU:", torch.cuda.get_device_name(0))
except ImportError:
    print("PyTorch: not installed")

# Host name (Colab will display google related domain names)
import socket
print("Hostname:", socket.gethostname())
# Out:
# Python: 3.12.13
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# Operating environment: ✅ Google Colab cloud
# PyTorch CUDA: ❌ Not available
# Hostname: 13c5169f5dd9
